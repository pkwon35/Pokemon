# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  #make plots prettier

# %%
df= pd.read_csv("C:/Users/pkwon_000/Desktop/Data Science Project/Pokemon/Pokemon.csv")

df.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0       65       65     45           1     False
# ...

# %%
df.columns=df.columns.str.lower()

df.columns=df.columns.str.replace(" ","")

df.columns=df.columns.str.replace("1","One")
df.columns=df.columns.str.replace("2","Two")
df.head()
# Out:
#    #                   name typeOne typeTwo  total  hp  attack  defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander    Fire     NaN    309  39      52       43
#
#    sp.atk  sp.def  speed  generation legendary
# 0      65      65     45           1     False
# 1      80      80     60           1     False
# 2     100     100     80           1     False
# 3     122     120     80           1     False
# 4      60      50     65           1     False

# %%
df=df.set_index('name')   # set the index with name
df.head(10)
# Out:
#                            # typeOne typeTwo  total  hp  attack  defense  \
# name
# Bulbasaur                  1   Grass  Poison    318  45      49       49
# Ivysaur                    2   Grass  Poison    405  60      62       63
# Venusaur                   3   Grass  Poison    525  80      82       83
# VenusaurMega Venusaur      3   Grass  Poison    625  80     100      123
# Charmander                 4    Fire     NaN    309  39      52       43
# Charmeleon                 5    Fire     NaN    405  58      64       58
# Charizard                  6    Fire  Flying    534  78      84       78
# CharizardMega Charizard X  6    Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y  6    Fire  Flying    634  78     104       78
# Squirtle                   7   Water     NaN    314  44      48       65
#
#                            sp.atk  sp.def  speed  generation legendary
# name
# Bulbasaur                      65      65     45           1     False
# ...

# %%
df.index=df.index.str.replace(".*(Mega=?)","")
df.head(100)
# Out:
#                #   typeOne  typeTwo  total   hp  attack  defense  sp.atk  \
# name
# Bulbasaur      1     Grass   Poison    318   45      49       49      65
# Ivysaur        2     Grass   Poison    405   60      62       63      80
# Venusaur       3     Grass   Poison    525   80      82       83     100
#  Venusaur      3     Grass   Poison    625   80     100      123     122
# Charmander     4      Fire      NaN    309   39      52       43      60
# Charmeleon     5      Fire      NaN    405   58      64       58      80
# Charizard      6      Fire   Flying    534   78      84       78     109
#  Charizard X   6      Fire   Dragon    634   78     130      111     130
#  Charizard Y   6      Fire   Flying    634   78     104       78     159
# Squirtle       7     Water      NaN    314   44      48       65      50
# Wartortle      8     Water      NaN    405   59      63       80      65
# Blastoise      9     Water      NaN    530   79      83      100      85
# ...

# %%
df=df.drop(['legendary','#'],axis=1)

# %%
# function to make nth column into a array
#def ArrayColumn(NthColumn):
 #   output = []
#  for line in df:
   #     cells = line.split( "," )
    #    output.append((cells[NthColumn])) 
    
    #return (output)

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['typeOne', 'typeTwo', 'total', 'hp', 'attack', 'defense', 'sp.atk',
#        'sp.def', 'speed', 'generation'],
#       dtype='object')
# (800, 10)

# %%
print(df.loc['Ivysaur'])

# able to retrieve all data from that row with 'Name'
# Out:
# typeOne        Grass
# typeTwo       Poison
# total            405
# hp                60
# attack            62
# defense           63
# sp.atk            80
# sp.def            80
# speed             60
# generation         1
# Name: Ivysaur, dtype: object

# %%
print(df.iloc[2])
# Out:
# typeOne        Grass
# typeTwo       Poison
# total            525
# hp                80
# attack            82
# defense           83
# sp.atk           100
# sp.def           100
# speed             80
# generation         1
# Name: Venusaur, dtype: object

# %%
df[((df['typeOne']=='Water')|(df['typeOne']=='Dragon'))]
# Out:
#                      typeOne   typeTwo  total   hp  attack  defense  sp.atk  \
# name
# Squirtle               Water       NaN    314   44      48       65      50
# Wartortle              Water       NaN    405   59      63       80      65
# Blastoise              Water       NaN    530   79      83      100      85
#  Blastoise             Water       NaN    630   79     103      120     135
# Psyduck                Water       NaN    320   50      52       48      65
# Golduck                Water       NaN    500   80      82       78      95
# Poliwag                Water       NaN    300   40      50       40      40
# Poliwhirl              Water       NaN    385   65      65       65      50
# Poliwrath              Water  Fighting    510   90      95       95      70
# Tentacool              Water    Poison    335   40      40       35      50
# Tentacruel             Water    Poison    515   80      70       65      80
# ...

# %%
df['attack'].argmin()
# Out:
# 'Chansey'

# %%
df['attack'].argmax()
# Out:
# ' Mewtwo X'

# %%
print(df.sort('total', ascending=True).head())
# Out:
#           typeOne typeTwo  total  hp  attack  defense  sp.atk  sp.def  speed  \
# name
# Sunkern     Grass     NaN    180  30      30       30      30      30     30
# Azurill    Normal   Fairy    190  50      20       40      20      40     20
# Kricketot     Bug     NaN    194  37      25       41      25      41     25
# Wurmple       Bug     NaN    195  45      45       35      20      30     20
# Weedle        Bug  Poison    195  40      35       30      20      20     50
#
#            generation
# name
# Sunkern             2
# Azurill             3
# Kricketot           4
# Wurmple             3
# Weedle              1
# C:\Users\pkwon_000\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
typeOnes=df['typeOne'].unique()
typeOnes
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
typeOnes[-1]
# Out:
# 'Flying'

# %%
CountTypes = df['typeOne'].value_counts()
print(CountTypes)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: typeOne, dtype: int64

# %%
summary=df.describe()
summary
# Out:
#            total          hp      attack     defense      sp.atk      sp.def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             speed  generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
plt.figure(figsize=(11,12))

# %%
water='b'

typeColor=[water,'silver', 'g','tan','darkorchid','r','k','yellow','white','brown','goldenrod','midnightblue','indigo', 'orange','slategray','turquoise','lightpink','aqua']

# %%
typeColor
# Out:
# ['b',
#  'silver',
#  'g',
#  'tan',
#  'darkorchid',
#  'r',
#  'k',
#  'yellow',
#  'white',
#  'brown',
#  'goldenrod',
#  'midnightblue',
#  'indigo',
#  'orange',
#  'slategray',
#  'turquoise',
#  'lightpink',
#  'aqua']

# %%
for i in range(0, 18):
    plt.scatter(df['attack'][df['typeOne']==str(typeOnes[i])],df['defense'][df['typeOne']==str(typeOnes[i])],marker='o',color=typeColor[i],label=typeOnes[i])

plt.legend()
plt.show()
